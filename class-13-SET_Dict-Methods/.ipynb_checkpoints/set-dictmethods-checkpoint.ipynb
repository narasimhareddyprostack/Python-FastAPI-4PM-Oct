# %%
employees=({'eid':101},{'eid':102},{'eid':103})
employees.insert(1,{'eid':104})
print(len(employees))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 employees=({'eid':101},{'eid':102},{'eid':103})
# ----> 2 employees.insert(1,{'eid':104})
#       3 print(len(employees))
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
employees=[{'eid':101},{'eid':102},{'eid':103}]
employees.insert(1,{'eid':104})
print(len(employees))
# Out:
# 4

# %%
eids={101,102,103,104}
#create
uids=eids.copy()  #return new set
print(uids)
# Out:
# {104, 101, 102, 103}

# %%
#update
eids={101,102,103}
eids.add(104)
print(eids)
# Out:
# {104, 101, 102, 103}

# %%
eids={101,102,103}
new_eids={101,104,105}  #dupicate
eids.update(new_eids)
print(eids)
# Out:
# {101, 102, 103, 104, 105}

# %%
#delete
eids={101,102,103}
eids.pop()  #remove arbitary element from set
print(eids)
# Out:
# {102, 103}

# %%
eids={101,102,103}
eids.remove(103) #remove specified element from set
                 #if element not present,it return ValueError
print(eids)
# Out:
# {101, 102}

# %%
eids={101,102,103}
eids.remove(104) #remove specified element from set
                 #if element not present,it return ValueError
print(eids)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 eids={101,102,103}
# ----> 2 eids.remove(104) #remove specified element from set
#       3                  #if element not present,it return ValueError
#       4 print(eids)
#
# KeyError: 104

# %%
eids={101,102,103}
eids.discard(103)
#remove specified element from set
#if element not present it will return any error
print(eids)
# Out:
# {101, 102}

# %%
eids={101,102,103}
eids.discard(104)
#remove specified element from set
#if element not present it will return any error
print(eids)
# Out:
# {101, 102, 103}

# %%
d1={}
print(type(d1))
# Out:
# <class 'dict'>

# %%
emp={'eid':101,'ename':'Rahul','esal':45000,'loc':'Wayanad'}
#create
#create new dict using dict.copy() method
user=emp.copy()
print(user)
#read
#update
#delete
# Out:
# {'eid': 101, 'ename': 'Rahul', 'esal': 45000, 'loc': 'Wayanad'}

# %%
emp={'eid':101,'ename':'Rahul','esal':45000,'loc':'Wayanad'}
#read
#read all keys , values  and key,value pairs
keys=emp.keys()
values=emp.values()
kv=emp.items()
print(keys)
print(values)
print(kv)
# Out:
# dict_keys(['eid', 'ename', 'esal', 'loc'])
# dict_values([101, 'Rahul', 45000, 'Wayanad'])
# dict_items([('eid', 101), ('ename', 'Rahul'), ('esal', 45000), ('loc', 'Wayanad')])
